# %%
import numpy as np
import pandas as pd

# %%
# !conda install -c anaconda xlrd
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - xlrd
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1g             |       h7b6447c_0         3.8 MB  anaconda
#     xlrd-1.2.0                 |             py_0         108 KB  anaconda
#     ca-certificates-2020.7.22  |                0         132 KB  anaconda
#     certifi-2020.6.20          |           py36_0         160 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         4.2 MB
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.7.22-0       --> 2020.7.22-0       anaconda
#     certifi:         2020.6.20-py36_0  --> 2020.6.20-py36_0  anaconda
# ...

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_db7426c033b04f128cfb16c5b6bb60d6 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='gW-nN4qj5T50ohCk36SEeYijSUP9VwcR7RcPnaiNDbrs',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_db7426c033b04f128cfb16c5b6bb60d6.get_object(Bucket='projecta-donotdelete-pr-4zbssd9izrpdn1',Key='A.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_0 = pd.read_excel(body)
df_data_0.head()
# Out:
#    Timestamp            Network_packet
# 0          1  fhgsret64567rysdfg5e646t
# 1          2      4565ertgdfh5e645yhfg
# 2          3              574565erhgfh
# 3          4  563456r5t76575678567trfy
# 4          5        64575ruy56uyfty657

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_head=df_data_0.head()

# %%
df_head.plot(kind='box')
plt.title('Network Traffic Analysis')
plt.xlabel('network Packets');
plt.ylabel('Timestamps');
plt.show()
